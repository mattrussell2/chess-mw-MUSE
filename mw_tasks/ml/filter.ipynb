# %%
import pandas as pd 

df = pd.read_csv('pdata.csv', dtype={
                                    'STATUS': str, 'TRIAL_TYPE': str, 'BLOCK_TYPE': str, 
                                    'CORRECT': str, 'TASK_NAME': str, 'pid': str, 
                                    'isFirstThree': str, 'congruent': str, 'isNBack': str, 
                                    'stimfile': str, 'colorIgnore': str, 'colorDraw': str, 
                                    'reflected': str, 'letter': str, 'subject_id':str 
                                    }
)

df
# Out:
# /tmp/ipykernel_14572/1969350956.py:3: DtypeWarning: Columns (18,21,23,24,26,27,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('pdata.csv', dtype={
#               probe-0       probe-1       probe-2       probe-3    timestamp  \
# 0       -1.492449e-14  1.412970e-15 -3.885666e-14  1.471843e-14      0.00000
# 1        4.499527e-01 -2.706121e+01 -8.518568e+01 -4.499527e-01      3.90625
# 2        3.070428e+00  2.218302e+01 -2.950903e+01 -3.070428e+00      7.81250
# 3       -2.566378e+00  2.753268e+01  1.062564e+02  2.566378e+00     11.71875
# 4       -2.674406e+01 -1.948315e+02  1.210599e+02  2.674406e+01     15.62500
# ...               ...           ...           ...           ...          ...
# 4590115 -6.712365e+00 -4.060486e+02 -7.609346e+01  6.712365e+00  93683.59375
# 4590116 -2.262175e+01 -4.046702e+02 -7.060745e+01  2.262175e+01  93687.50000
# 4590117 -4.868430e+01 -3.662560e+02 -6.245496e+01  4.868430e+01  93691.40625
# ...

# %%
import numpy as np
# for key in df.keys():
#     print(f"{key} - {df[key].unique()}")

print(len(df['trial_id'].unique()))

# for pid, pid_df in df.groupby(['pid']):
#     print(f"{pid} - {len(pid_df['trial_id'].unique())}")
#2232297 na rows
# subdf = df[(df['STATUS'] == 'trial_loaded') | (df['STATUS'] == 'trial_finished')]
# print(subdf['TRIAL_TYPE'])
# for i, row in df.iterrows():
#     if i != 0 and row['STATUS'] == 'trial_loaded':
#         print(row['TRIAL_TYPE'])
# Out:
# ('0cbaf29f',) - 755
# ('239022dd',) - 755
# ('5dbdbc27',) - 726
# ('67da2976',) - 832
# ('7f2c0be7',) - 774
# ('86a4a2ac',) - 679
# ('992cdda3',) - 699
# ('b07e0a64',) - 769
# ('b86bd471',) - 783
